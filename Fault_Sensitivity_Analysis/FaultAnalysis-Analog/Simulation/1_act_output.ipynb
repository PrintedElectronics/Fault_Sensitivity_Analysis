# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('./ptanh_fault.csv')
data
# Out:
#           X  /R1_data_open  Y  /R1_data_short  Y  /R2_data_open  Y  \
# 0    -2.000          0.999975          -0.558562         -31.48740
# 1    -1.999          0.999975          -0.558561         -31.48740
# 2    -1.998          0.999975          -0.558561         -31.48740
# 3    -1.997          0.999975          -0.558561         -31.48740
# 4    -1.996          0.999975          -0.558561         -31.48740
# ...     ...               ...                ...               ...
# 3996  1.996          0.999975          -0.558561          -2.36678
# 3997  1.997          0.999975          -0.558561          -2.36678
# 3998  1.998          0.999975          -0.558561          -2.36678
# 3999  1.999          0.999975          -0.558561          -2.36678
# 4000  2.000          0.999975          -0.558561          -2.36678
#
#       /R2_data_short  Y  /M1_G-S_short  Y  /M1_open  Y  /M1_D-S_short  Y  \
# 0                     1          0.473838    -0.558562          0.999975
# ...

# %% [markdown]
# # 无用列

# %%
a = torch.tensor(data.to_numpy())[:,1:]
a.shape
# Out:
# torch.Size([4001, 12])

# %%
torch.save(a, './ptanh_fault.data')
