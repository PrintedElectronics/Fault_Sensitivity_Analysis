# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('./neg_fault.csv')
data
# Out:
#           X  /R1_open Y  /R1_short Y  /R2_open Y  /R2_short Y  /R3_open Y  \
# 0    -2.000   -0.839072     0.606441    0.999919    -0.839073    -31.4819
# 1    -1.999   -0.839072     0.606470    0.999919    -0.839073    -31.4819
# 2    -1.998   -0.839072     0.606470    0.999919    -0.839073    -31.4819
# 3    -1.997   -0.839072     0.606470    0.999919    -0.839073    -31.4819
# 4    -1.996   -0.839072     0.606470    0.999919    -0.839073    -31.4819
# ...     ...         ...          ...         ...          ...         ...
# 3996  1.996   -0.839072     0.606470    0.999919    -0.839073    -31.4876
# 3997  1.997   -0.839072     0.606470    0.999919    -0.839073    -31.4876
# 3998  1.998   -0.839072     0.606470    0.999919    -0.839073    -31.4876
# 3999  1.999   -0.839072     0.606470    0.999919    -0.839073    -31.4876
# 4000  2.000   -0.839072     0.606470    0.999919    -0.839073    -31.4876
#
#       /R3_short Y  /M1_G-S_short Y  /M1_open Y  /M1_G-D_short Y  \
# 0               1         0.532221    0.606441        -0.839072
# 1               1         0.532253    0.606470        -0.839072
# 2               1         0.532286    0.606470        -0.839072
# 3               1         0.532318    0.606470        -0.839072
# 4               1         0.532350    0.606470        -0.839072
# ...           ...              ...         ...              ...
# 3996            1         0.646813    0.606470         0.700164
# 3997            1         0.646888    0.606470         0.700228
# 3998            1         0.646964    0.606470         0.700292
# 3999            1         0.647039    0.606470         0.700355
# 4000            1         0.647115    0.606470         0.700419
#
#       /M1_D-S_short Y  /M2_D-S_short Y  /M2_G-D_short Y  /M2_G-S_short Y  \
# 0           -0.839072         0.999919        -0.772894        -0.839072
# 1           -0.839072         0.999919        -0.772832        -0.839072
# 2           -0.839072         0.999919        -0.772832        -0.839072
# 3           -0.839072         0.999919        -0.772832        -0.839072
# 4           -0.839072         0.999919        -0.772832        -0.839072
# ...               ...              ...              ...              ...
# 3996        -0.839072         0.999919        -0.756610        -0.839072
# 3997        -0.839072         0.999919        -0.756605        -0.839072
# 3998        -0.839072         0.999919        -0.756599        -0.839072
# 3999        -0.839072         0.999919        -0.756594        -0.839072
# 4000        -0.839072         0.999919        -0.756589        -0.839072
#
#       /M2_open Y  /M3_open Y  /M3_D-S_short Y  /M3_G-D_short Y  \
# 0      -0.839073           1               -1        -0.680590
# 1      -0.839073           1               -1        -0.680590
# 2      -0.839073           1               -1        -0.680590
# 3      -0.839073           1               -1        -0.680590
# 4      -0.839073           1               -1        -0.680590
# ...          ...         ...              ...              ...
# 3996   -0.839073           1               -1         0.800554
# 3997   -0.839073           1               -1         0.800555
# 3998   -0.839073           1               -1         0.800557
# 3999   -0.839073           1               -1         0.800558
# 4000   -0.839073           1               -1         0.800559
#
#       /M3_G-S_short Y
# 0            0.999919
# 1            0.999919
# 2            0.999919
# 3            0.999919
# 4            0.999919
# ...               ...
# 3996         0.999919
# 3997         0.999919
# 3998         0.999919
# 3999         0.999919
# 4000         0.999919
#
# [4001 rows x 19 columns]

# %% [markdown]
# # 无用列

# %%
a = torch.tensor(data.to_numpy())[:,1:]
a.shape
# Out:
# torch.Size([4001, 18])

# %%
torch.save(a, './neg_fault.data')
